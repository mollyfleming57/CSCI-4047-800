# %% [markdown]
# # Assignment 1
# Here we are -- Data Analytics time! WoOooooOOoOoo!
# ---
# ### Instructions
#
# Type `pip install pandas` in a teminal to ensure you have the package installed.
#
# 1. Using what we went over in class during the Jupyter tutorial, load in the data found in the **Income Data.csv** file
#     - Create a dataframe with `pandas`
# 2. Print that dataframe using a `print` statement or `df.head()`
#
# Do these steps in the code block below (you may delete the comment if you'd like).

# %%
import pandas, numpy, sklearn, seaborn, statsmodels, matplotlib
print("Environment ready")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas, numpy, seaborn, statsmodels, matplotlib
#       2 print("Environment ready")
#
# File ~\miniconda3\envs\analytics\Lib\site-packages\seaborn\__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File ~\miniconda3\envs\analytics\Lib\site-packages\seaborn\rcmod.py:3
#       1 """Control plot style and scaling using the matplotlib rcParams interface."""
#       2 import functools
# ----> 3 import matplotlib as mpl
#       4 from cycler import cycler
#       5 from . import palettes
#
# File ~\miniconda3\envs\analytics\Lib\site-packages\matplotlib\__init__.py:990
#     984     _log.debug('loaded rc file %s', fname)
#     986     return config
#     989 rcParamsDefault = _rc_params_in_file(
# --> 990     cbook._get_data_path("matplotlibrc"),
#     991     # Strip leading comment.
#     992     transform=lambda line: line[1:] if line.startswith("#") else line,
#     993     fail_on_error=True)
#     994 rcParamsDefault._update_raw(rcsetup._hardcoded_defaults)
#     995 rcParamsDefault._ensure_has_backend()
#
# File ~\miniconda3\envs\analytics\Lib\site-packages\matplotlib\cbook.py:632, in _get_data_path(*args)
#     626 def _get_data_path(*args):
#     627     """
#     628     Return the `pathlib.Path` to a resource file provided by Matplotlib.
#     629
#     630     ``*args`` specify a path relative to the base data path.
#     631     """
# --> 632     return Path(matplotlib.get_data_path(), *args)
#
# File ~\miniconda3\envs\analytics\Lib\site-packages\matplotlib\_api\__init__.py:318, in caching_module_getattr.<locals>.__getattr__(name)
#     316 if name in props:
#     317     return props[name].__get__(instance)
# --> 318 raise AttributeError(
#     319     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'

# %%
# Code goes here

# %% [markdown]
# 3. What's one thing you're proud of yourself for this week, and what's your biggest phobia?

# %% [markdown]
# 4. Submit this `Jupyter` file to D2L, renamed as **Last_First_Assignment1.ipynb**
#     - Replace '**Last**' and '**First**' with your name
